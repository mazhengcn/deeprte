# %%
# %tensorboard

# %%
import os
from pathlib import Path

# os.environ["CUDA_VISIBLE_DEVICES"] = "4, 7"
os.chdir(Path.cwd().parent)

# %%
# !./run.sh
# Out:
# I1207 09:36:02.184642 140125851014336 train.py:78] Training with config:
# best_model_eval_metric: ''
# best_model_eval_metric_higher_is_better: true
# checkpoint_dir: !!python/object/apply:pathlib.PosixPath
# - data
# - ckpt
# checkpoint_interval_type: null
# eval_initial_weights: false
# experiment_kwargs:
#   config:
#     dataset:
#       buffer_size: 500
#       data_path: data/rte/rte_2d_converted.npz
#       max_intra_op_parallelism: 1
#       threadpool_size: 48
#     evaluation:
#       batch_size: 100
#       interval: 333
#     optimizer:
#       adam_kwargs: {}
#       base_lr: 0.001
#       exponential_decay_kwargs:
#         decay_rate: 0.96
#         transition_steps: 100
#       optimizer: adam
#       scale_by_batch: false
#       schedule_type: constant
#     save_final_checkpoint_as_npy: false
#     training:
#       batch_size: 12
#       collocation_sizes: 500
#       num_epochs: 100
#       num_train_examples: 400
#       repeat: 1
# interval_type: steps
# ...
