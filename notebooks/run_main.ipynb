# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
import os

os.chdir("/workspaces/deeprte")

# !./run.sh
# Out:
# I1212 08:25:01.918208 140568550164224 train.py:84] Training with config:
# best_model_eval_metric: ''
# best_model_eval_metric_higher_is_better: true
# checkpoint_dir: ./data/ckpt
# checkpoint_interval_type: null
# eval_initial_weights: false
# experiment_kwargs:
#   config:
#     dataset:
#       buffer_size: 5000
#       data_path: data/rte/rte_2d_converted.npz
#       max_intra_op_parallelism: 1
#       threadpool_size: 48
#     evaluation:
#       batch_size: 100
#     model:
#       constructor: !!python/name:deeprte.models.rte.RTESupervised ''
#       kwargs:
#         name: rte
#     optimizer:
#       adam_kwargs: {}
#       base_lr: 0.001
#       exponential_decay_kwargs:
#         decay_rate: 0.96
#         transition_steps: 100
#       optimizer: adam
#       scale_by_batch: false
#       schedule_type: constant
#     solution:
#       constructor: !!python/name:deeprte.solution.RTEOperator ''
#       kwargs:
#         config:
#           green_function:
# ...

# %%
# %tensorboard --logdir ../data/ckpt
# Out:
# Reusing TensorBoard on port 6006 (pid 250366), started 2:52:05 ago. (Use '!kill 250366' to kill it.)
#       <iframe id="tensorboard-frame-401a34bbb38b652b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-401a34bbb38b652b");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
